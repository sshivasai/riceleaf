# %%
from tensorflow.keras.models import load_model

# %%
from tensorflow.keras.preprocessing.image import load_img,img_to_array

# %%
img = load_img("Data/train/Brown spot/brown_spot_0_9.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x1855837D550>

# %%
img = img.resize((256,256))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x185D545B4C0>

# %%
img = img_to_array(img)

# %%
img = img.reshape((1,256,256,3))/255

# %%
model = load_model("bestmodel.h5")

# %%
pred = model.predict(img)

# %%
import numpy as np
np.argmax(pred)
# Out:
# 1
